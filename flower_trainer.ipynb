# %%
#importing the necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
#importing the dataset
names = ['sepal-length','sepal-width','petal-length','petal-width','Class']
dataset = pd.read_csv('iris.data',names=names)

# %%
dataset.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dataset.shape
# Out:
# (150, 5)

# %%
X = dataset.iloc[:,:-1]

# %%
X.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y = dataset.iloc[:,4]

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Class, dtype: object

# %%
#splitting the dataset into test and train datasets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
x_train.head(1)
# Out:
#     sepal-length  sepal-width  petal-length  petal-width
# 27           5.2          3.5           1.5          0.2

# %%
#training and saving the model
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train,y_train)
filename = 'flower_model.sav'
pickle.dump(model,open(filename,'wb'))

# %%
#predicting the results on test data
y_pred = model.predict(x_test)

# %%
#displaying the accuracy
from sklearn import metrics
print("Accuracy is ",metrics.accuracy_score(y_pred,y_test)*100)
print("Confusion Matrix ",metrics.confusion_matrix(y_pred,y_test)*100)
print("Report ",metrics.classification_report(y_pred,y_test)*100)
# Out:
# Accuracy is  96.66666666666667
# Confusion Matrix  [[1600    0    0]
#  [   0  800  100]
#  [   0    0  500]]
# Report                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      0.89      0.94         9
#  Iris-virginica       0.83      1.00      0.91         5
#
#       micro avg       0.97      0.97      0.97        30
#       macro avg       0.94      0.96      0.95        30
#    weighted avg       0.97      0.97      0.97        30
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      0.89      0.94         9
#  Iris-virginica       0.83      1.00      0.91         5
#
#       micro avg       0.97      0.97      0.97        30
#       macro avg       0.94      0.96      0.95        30
#    weighted avg       0.97      0.97      0.97        30
# ...
